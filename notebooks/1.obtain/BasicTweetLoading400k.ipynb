# %%
import json
import time
import pandas as pd
import os

# %%
#Support Functions:
#List[JSON Object] -> String[URL]
#Purpose: To inspect tweets on twitter, use this funciton to pass JSON objects and generate
#URLS to examine in the browser.
def tweeturlgen(jsonlist):
    baseURL = "https://twitter.com/" 
    urlList = []
    for obj in jsonlist:
        urlList.append(baseURL + obj['user']['screen_name'] + "/status/" + obj['id_str'])
    return urlList

# %% [markdown]
# ### Start:
#
# First, lets look at what JSON tweet objects look like. A sample of 5 tweet objects is below:

# %%
tweets_data = []
with open("./data/fiveline.json", "r") as tweets_file:
    for line in tweets_file:
        try:
            tweet = json.loads(line)
            tweets_data.append(tweet)
        except:
            continue
            
tweets_data
# Out:
# [{'created_at': 'Fri Sep 27 19:03:37 +0000 2019',
#   'id': 1177660079400800258,
#   'id_str': '1177660079400800258',
#   'text': 'RT @tylerwhat16: Y’all better be going out like this to vote on Oct. 21! #ClimateChange #ClimateStrikeCanada #climatestriketoronto #ONPoli…',
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 39512124,
#    'id_str': '39512124',
#    'name': 'Under the Radar',
#    'screen_name': 'retail_recruit',
#    'location': 'I mute with reckless abandon. #INTJ',
#    'url': None,
#    'description': "Small L liberal. 🇨🇦 Int'l Politics/ History pro. Still a fashionista in cosmopolitan #Montréal-snark, progressive, festivals, culture, art, fashion #Philotimo",
#    'translator_type': 'regular',
#    'protected': False,
#    'verified': False,
#    'followers_count': 3389,
#    'friends_count': 4497,
#    'listed_count': 126,
#    'favourites_count': 179789,
#    'statuses_count': 129633,
#    'created_at': 'Tue May 12 14:38:17 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1062836106700488705/jKiJza6A_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1062836106700488705/jKiJza6A_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39512124/1545923730',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Sep 27 18:39:19 +0000 2019',
#    'id': 1177653964722061313,
#    'id_str': '1177653964722061313',
#    'text': 'Y’all better be going out like this to vote on Oct. 21! #ClimateChange #ClimateStrikeCanada #climatestriketoronto… https://t.co/EVsU5JRVKY',
#    'display_text_range': [0, 140],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 259602009,
#     'id_str': '259602009',
#     'name': 'Tyler Watt 🇨🇦',
#     'screen_name': 'tylerwhat16',
#     'location': 'Ontario, Canada',
#     'url': 'http://facebook.com/WattIsGoingOn',
#     'description': 'Here to unite progressives, make you laugh, & expose the truth • DM me news tips or other inquiries • #ONPoli #CDNPoli • 29 cis he/him 🏳️\u200d🌈 Tweets are my own',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 8673,
#     'friends_count': 1526,
#     'listed_count': 48,
#     'favourites_count': 14754,
#     'statuses_count': 7799,
#     'created_at': 'Wed Mar 02 06:17:00 +0000 2011',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1144059913603297280/k3Lq9_EU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1144059913603297280/k3Lq9_EU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/259602009/1552602483',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'quoted_status_id': 1177629057653121024,
#    'quoted_status_id_str': '1177629057653121024',
#    'quoted_status': {'created_at': 'Fri Sep 27 17:00:21 +0000 2019',
#     'id': 1177629057653121024,
#     'id_str': '1177629057653121024',
#     'text': 'Crowd update at Queens Park for #climatestriketoronto - As far as the eye can see. https://t.co/v9lu8DyJoe',
#     'display_text_range': [0, 82],
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 25575859,
#      'id_str': '25575859',
#      'name': 'Richard Southern',
#      'screen_name': 'richard680news',
#      'location': 'Toronto',
#      'url': 'http://tinyurl.com/gr8nxjm',
#      'description': 'Interesting, never boring stories. Queen’s Park reporter. Tips at richard.southern@rci.rogers.com On @680NEWS, @CityNews & Rogers stations coast to coast',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': True,
#      'followers_count': 5686,
#      'friends_count': 1180,
#      'listed_count': 152,
#      'favourites_count': 8763,
#      'statuses_count': 11567,
#      'created_at': 'Fri Mar 20 21:04:09 +0000 2009',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': '9AE4E8',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'BDDCAD',
#      'profile_sidebar_fill_color': 'DDFFCC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/858062470992326658/Nbzoxihq_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/858062470992326658/Nbzoxihq_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25575859/1409866874',
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'quote_count': 1,
#     'reply_count': 8,
#     'retweet_count': 45,
#     'favorite_count': 104,
#     'entities': {'hashtags': [{'text': 'climatestriketoronto',
#        'indices': [32, 53]}],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': [],
#      'media': [{'id': 1177627398893969408,
#        'id_str': '1177627398893969408',
#        'indices': [83, 106],
#        'additional_media_info': {'monetizable': False},
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#        'url': 'https://t.co/v9lu8DyJoe',
#        'display_url': 'pic.twitter.com/v9lu8DyJoe',
#        'expanded_url': 'https://twitter.com/richard680news/status/1177629057653121024/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1177627398893969408,
#        'id_str': '1177627398893969408',
#        'indices': [83, 106],
#        'additional_media_info': {'monetizable': False},
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#        'url': 'https://t.co/v9lu8DyJoe',
#        'display_url': 'pic.twitter.com/v9lu8DyJoe',
#        'expanded_url': 'https://twitter.com/richard680news/status/1177629057653121024/video/1',
#        'type': 'video',
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 14900,
#         'variants': [{'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/vid/480x270/Rtok76ZzVHPJcrNw.mp4?tag=10'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/vid/1280x720/2nul6E0nsEdD_OJd.mp4?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/vid/640x360/evTGjqJxFUBLQbBX.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/pl/3nb1IQE_FUTNBpgJ.m3u8?tag=10'}]},
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'filter_level': 'low',
#     'lang': 'en'},
#    'quoted_status_permalink': {'url': 'https://t.co/xKpPfmHhU5',
#     'expanded': 'https://twitter.com/richard680news/status/1177629057653121024',
#     'display': 'twitter.com/richard680news…'},
#    'is_quote_status': True,
#    'extended_tweet': {'full_text': 'Y’all better be going out like this to vote on Oct. 21! #ClimateChange #ClimateStrikeCanada #climatestriketoronto #ONPoli #CDNPoli #elxn43 https://t.co/xKpPfmHhU5',
#     'display_text_range': [0, 138],
#     'entities': {'hashtags': [{'text': 'ClimateChange', 'indices': [56, 70]},
#       {'text': 'ClimateStrikeCanada', 'indices': [71, 91]},
#       {'text': 'climatestriketoronto', 'indices': [92, 113]},
#       {'text': 'ONPoli', 'indices': [114, 121]},
#       {'text': 'CDNPoli', 'indices': [122, 130]},
#       {'text': 'elxn43', 'indices': [131, 138]}],
#      'urls': [{'url': 'https://t.co/xKpPfmHhU5',
#        'expanded_url': 'https://twitter.com/richard680news/status/1177629057653121024',
#        'display_url': 'twitter.com/richard680news…',
#        'indices': [139, 162]}],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 7,
#    'retweet_count': 40,
#    'favorite_count': 105,
#    'entities': {'hashtags': [{'text': 'ClimateChange', 'indices': [56, 70]},
#      {'text': 'ClimateStrikeCanada', 'indices': [71, 91]},
#      {'text': 'climatestriketoronto', 'indices': [92, 113]}],
#     'urls': [{'url': 'https://t.co/EVsU5JRVKY',
#       'expanded_url': 'https://twitter.com/i/web/status/1177653964722061313',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [115, 138]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_id': 1177629057653121024,
#   'quoted_status_id_str': '1177629057653121024',
#   'quoted_status': {'created_at': 'Fri Sep 27 17:00:21 +0000 2019',
#    'id': 1177629057653121024,
#    'id_str': '1177629057653121024',
#    'text': 'Crowd update at Queens Park for #climatestriketoronto - As far as the eye can see. https://t.co/v9lu8DyJoe',
#    'display_text_range': [0, 82],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': False,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25575859,
#     'id_str': '25575859',
#     'name': 'Richard Southern',
#     'screen_name': 'richard680news',
#     'location': 'Toronto',
#     'url': 'http://tinyurl.com/gr8nxjm',
#     'description': 'Interesting, never boring stories. Queen’s Park reporter. Tips at richard.southern@rci.rogers.com On @680NEWS, @CityNews & Rogers stations coast to coast',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 5686,
#     'friends_count': 1180,
#     'listed_count': 152,
#     'favourites_count': 8763,
#     'statuses_count': 11567,
#     'created_at': 'Fri Mar 20 21:04:09 +0000 2009',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/858062470992326658/Nbzoxihq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/858062470992326658/Nbzoxihq_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25575859/1409866874',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'quote_count': 1,
#    'reply_count': 8,
#    'retweet_count': 45,
#    'favorite_count': 104,
#    'entities': {'hashtags': [{'text': 'climatestriketoronto',
#       'indices': [32, 53]}],
#     'urls': [],
#     'user_mentions': [],
#     'symbols': [],
#     'media': [{'id': 1177627398893969408,
#       'id_str': '1177627398893969408',
#       'indices': [83, 106],
#       'additional_media_info': {'monetizable': False},
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#       'url': 'https://t.co/v9lu8DyJoe',
#       'display_url': 'pic.twitter.com/v9lu8DyJoe',
#       'expanded_url': 'https://twitter.com/richard680news/status/1177629057653121024/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1177627398893969408,
#       'id_str': '1177627398893969408',
#       'indices': [83, 106],
#       'additional_media_info': {'monetizable': False},
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1177627398893969408/pu/img/ifmSQfpTfJy-4Twg.jpg',
#       'url': 'https://t.co/v9lu8DyJoe',
#       'display_url': 'pic.twitter.com/v9lu8DyJoe',
#       'expanded_url': 'https://twitter.com/richard680news/status/1177629057653121024/video/1',
#       'type': 'video',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 14900,
#        'variants': [{'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/vid/480x270/Rtok76ZzVHPJcrNw.mp4?tag=10'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/vid/1280x720/2nul6E0nsEdD_OJd.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/vid/640x360/evTGjqJxFUBLQbBX.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1177627398893969408/pu/pl/3nb1IQE_FUTNBpgJ.m3u8?tag=10'}]},
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/xKpPfmHhU5',
#    'expanded': 'https://twitter.com/richard680news/status/1177629057653121024',
#    'display': 'twitter.com/richard680news…'},
#   'is_quote_status': True,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'ClimateChange', 'indices': [73, 87]},
#     {'text': 'ClimateStrikeCanada', 'indices': [88, 108]},
#     {'text': 'climatestriketoronto', 'indices': [109, 130]},
#     {'text': 'ONPoli', 'indices': [131, 138]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'tylerwhat16',
#      'name': 'Tyler Watt 🇨🇦',
#      'id': 259602009,
#      'id_str': '259602009',
#      'indices': [3, 15]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1569611017452'},
#  {'created_at': 'Fri Sep 27 19:03:37 +0000 2019',
#   'id': 1177660081082519553,
#   'id_str': '1177660081082519553',
#   'text': 'RT @AndreeLyne_H: Justin Trudeau is promising that a re-elected Liberal government would pay for the planting of two billion trees over the…',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16272844,
#    'id_str': '16272844',
#    'name': 'Greg Johansen 🏳️\u200d🌈 🐓🍷',
#    'screen_name': 'johangreg',
#    'location': '#yyc #yyccentre @FlyYYC',
#    'url': None,
#    'description': 'Sports fanatic • #LGBTQ2 • #Aspergers • #cdnpoli tweet from the heart and soul, and usually inappropriately ¯\\_(ツ)_/¯ johansengreg@hotmail.com',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 3198,
#    'friends_count': 1179,
#    'listed_count': 592,
#    'favourites_count': 220678,
#    'statuses_count': 497449,
#    'created_at': 'Sat Sep 13 16:04:25 +0000 2008',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1171813722743955461/rlsCyMC3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1171813722743955461/rlsCyMC3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16272844/1568217138',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Sep 27 17:25:31 +0000 2019',
#    'id': 1177635389852524545,
#    'id_str': '1177635389852524545',
#    'text': 'Justin Trudeau is promising that a re-elected Liberal government would pay for the planting of two billion trees ov… https://t.co/B4Hz8og7Vi',
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 549706370,
#     'id_str': '549706370',
#     'name': 'Andrée-Lyne Hallé',
#     'screen_name': 'AndreeLyne_H',
#     'location': None,
#     'url': None,
#     'description': 'Senior Advisor, Team Trudeau ✈️🚌🇨🇦 | Fière méganticoise. Fan finie de F1 et du CH.',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 3022,
#     'friends_count': 2998,
#     'listed_count': 94,
#     'favourites_count': 919,
#     'statuses_count': 14928,
#     'created_at': 'Tue Apr 10 01:34:16 +0000 2012',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2090182392/image_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2090182392/image_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/549706370/1557713250',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'Justin Trudeau is promising that a re-elected Liberal government would pay for the planting of two billion trees over the next decade to combat climate change\n\n#elxn43 #polcan #cdnpoli\n#ChooseForward #Choisirdavancer  https://t.co/0BRtUXRLuF',
#     'display_text_range': [0, 241],
#     'entities': {'hashtags': [{'text': 'elxn43', 'indices': [160, 167]},
#       {'text': 'polcan', 'indices': [168, 175]},
#       {'text': 'cdnpoli', 'indices': [176, 184]},
#       {'text': 'ChooseForward', 'indices': [185, 199]},
#       {'text': 'Choisirdavancer', 'indices': [200, 216]}],
#      'urls': [{'url': 'https://t.co/0BRtUXRLuF',
#        'expanded_url': 'https://election.ctvnews.ca/trudeau-promises-liberals-would-plant-2-billion-trees-1.4613506',
#        'display_url': 'election.ctvnews.ca/trudeau-promis…',
#        'indices': [218, 241]}],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 3,
#    'favorite_count': 12,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/B4Hz8og7Vi',
#       'expanded_url': 'https://twitter.com/i/web/status/1177635389852524545',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'AndreeLyne_H',
#      'name': 'Andrée-Lyne Hallé',
#      'id': 549706370,
#      'id_str': '549706370',
#      'indices': [3, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1569611017853'},
#  {'created_at': 'Fri Sep 27 19:03:37 +0000 2019',
#   'id': 1177660081388871681,
#   'id_str': '1177660081388871681',
#   'text': 'RT @TheBeaverton: Trudeau comes to Montreal climate strike to protest self #cdnpoli #elxn43 #ClimateStrikeCanada',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2393055440,
#    'id_str': '2393055440',
#    'name': 'Darren Cargill 🇨🇦',
#    'screen_name': 'reasonablewlvrn',
#    'location': 'Windsor, ON',
#    'url': None,
#    'description': 'Father, Husband, PallMed MD in Windsor, ON. Going 🐝  RT = chat. Spelling 🚫 part of plan. speak GIPHY & 🙅🏼\u200d trolls. Not a Bot #TrudeauMustGo #GoBlue #TB12🐐',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2578,
#    'friends_count': 1910,
#    'listed_count': 109,
#    'favourites_count': 39860,
#    'statuses_count': 31072,
#    'created_at': 'Sun Mar 16 17:39:32 +0000 2014',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1120864160349343744/nPbhW5nl_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1120864160349343744/nPbhW5nl_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2393055440/1569180436',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Sep 27 18:56:36 +0000 2019',
#    'id': 1177658314345324544,
#    'id_str': '1177658314345324544',
#    'text': 'Trudeau comes to Montreal climate strike to protest self #cdnpoli #elxn43 #ClimateStrikeCanada',
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'truncated': False,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 149282848,
#     'id_str': '149282848',
#     'name': 'The Beaverton',
#     'screen_name': 'TheBeaverton',
#     'location': 'North America',
#     'url': 'http://www.thebeaverton.com',
#     'description': 'Finally. The News. On Television. Watch our damn Election Special October 18th on @CTV',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 47330,
#     'friends_count': 288,
#     'listed_count': 459,
#     'favourites_count': 4967,
#     'statuses_count': 11768,
#     'created_at': 'Fri May 28 22:18:50 +0000 2010',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': 'CC0000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1064609270233128960/e4KT53qW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1064609270233128960/e4KT53qW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/149282848/1565189994',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'quote_count': 0,
#    'reply_count': 4,
#    'retweet_count': 22,
#    'favorite_count': 50,
#    'entities': {'hashtags': [{'text': 'cdnpoli', 'indices': [57, 65]},
#      {'text': 'elxn43', 'indices': [66, 73]},
#      {'text': 'ClimateStrikeCanada', 'indices': [74, 94]}],
#     'urls': [],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'cdnpoli', 'indices': [75, 83]},
#     {'text': 'elxn43', 'indices': [84, 91]},
#     {'text': 'ClimateStrikeCanada', 'indices': [92, 112]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'TheBeaverton',
#      'name': 'The Beaverton',
#      'id': 149282848,
#      'id_str': '149282848',
#      'indices': [3, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1569611017926'},
#  {'created_at': 'Fri Sep 27 19:03:39 +0000 2019',
#   'id': 1177660086635753472,
#   'id_str': '1177660086635753472',
#   'text': 'RT @ewbcalgary: It may have rained and snowed ☔️🌨 today, but that didn’t stop us from showing up at #ClimateStrikeYYC.\n💪🌎\n\nHave you added y…',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1171638022787543040,
#    'id_str': '1171638022787543040',
#    'name': 'debwong',
#    'screen_name': 'deborahwongsy',
#    'location': 'Calgary, Alberta',
#    'url': None,
#    'description': 'I occasionally like to comment on politics and drink beers. Views are my own.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 16,
#    'friends_count': 83,
#    'listed_count': 0,
#    'favourites_count': 59,
#    'statuses_count': 25,
#    'created_at': 'Wed Sep 11 04:14:18 +0000 2019',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1171638896955973634/3eZm7Qf2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1171638896955973634/3eZm7Qf2_normal.jpg',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Sep 27 19:01:38 +0000 2019',
#    'id': 1177659582547496960,
#    'id_str': '1177659582547496960',
#    'text': 'It may have rained and snowed ☔️🌨 today, but that didn’t stop us from showing up at #ClimateStrikeYYC.\n💪🌎\n\nHave you… https://t.co/faBfHPxfAq',
#    'display_text_range': [0, 140],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 16153555,
#     'id_str': '16153555',
#     'name': 'EWB Calgary',
#     'screen_name': 'ewbcalgary',
#     'location': 'Calgary, Alberta',
#     'url': 'http://calgary.ewb.ca',
#     'description': 'Calgary Professional Chapter of Engineers Without Borders Canada',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 801,
#     'friends_count': 412,
#     'listed_count': 44,
#     'favourites_count': 199,
#     'statuses_count': 1742,
#     'created_at': 'Sat Sep 06 04:04:56 +0000 2008',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '7FA6A6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': True,
#     'profile_link_color': 'CD834A',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/468930586724143104/ZGCi9T9P_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/468930586724143104/ZGCi9T9P_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16153555/1569564369',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '53504716d445dcad',
#     'url': 'https://api.twitter.com/1.1/geo/id/53504716d445dcad.json',
#     'place_type': 'city',
#     'name': 'Calgary',
#     'full_name': 'Calgary, Alberta',
#     'country_code': 'CA',
#     'country': 'Canada',
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-114.316038, 50.84278],
#        [-114.316038, 51.212548],
#        [-113.859664, 51.212548],
#        [-113.859664, 50.84278]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'It may have rained and snowed ☔️🌨 today, but that didn’t stop us from showing up at #ClimateStrikeYYC.\n💪🌎\n\nHave you added your voice to our #campaign yet? 👉 https://t.co/5pfvtEarli\n\n#ClimateStrike #5Asks #EWB #Elxn43 #CndPoli #Environment #Calgary #YYC https://t.co/FGifxsfYPH',
#     'display_text_range': [0, 252],
#     'entities': {'hashtags': [{'text': 'ClimateStrikeYYC',
#        'indices': [84, 101]},
#       {'text': 'campaign', 'indices': [140, 149]},
#       {'text': 'ClimateStrike', 'indices': [182, 196]},
#       {'text': '5Asks', 'indices': [197, 203]},
#       {'text': 'EWB', 'indices': [204, 208]},
#       {'text': 'Elxn43', 'indices': [209, 216]},
#       {'text': 'CndPoli', 'indices': [217, 225]},
#       {'text': 'Environment', 'indices': [226, 238]},
#       {'text': 'Calgary', 'indices': [239, 247]},
#       {'text': 'YYC', 'indices': [248, 252]}],
#      'urls': [{'url': 'https://t.co/5pfvtEarli',
#        'expanded_url': 'http://bit.ly/CampaigningForChangeYYC',
#        'display_url': 'bit.ly/CampaigningFor…',
#        'indices': [157, 180]}],
#      'user_mentions': [],
#      'symbols': [],
#      'media': [{'id': 1177659574695821312,
#        'id_str': '1177659574695821312',
#        'indices': [253, 276],
#        'media_url': 'http://pbs.twimg.com/media/EFfjJMgVAAAIMBH.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EFfjJMgVAAAIMBH.jpg',
#        'url': 'https://t.co/FGifxsfYPH',
#        'display_url': 'pic.twitter.com/FGifxsfYPH',
#        'expanded_url': 'https://twitter.com/ewbcalgary/status/1177659582547496960/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#         'large': {'w': 1600, 'h': 1200, 'resize': 'fit'}}},
#       {'id': 1177659574716755968,
#        'id_str': '1177659574716755968',
#        'indices': [253, 276],
#        'media_url': 'http://pbs.twimg.com/media/EFfjJMlUcAAw_dO.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EFfjJMlUcAAw_dO.jpg',
#        'url': 'https://t.co/FGifxsfYPH',
#        'display_url': 'pic.twitter.com/FGifxsfYPH',
#        'expanded_url': 'https://twitter.com/ewbcalgary/status/1177659582547496960/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#         'large': {'w': 1600, 'h': 1200, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1177659574695821312,
#        'id_str': '1177659574695821312',
#        'indices': [253, 276],
#        'media_url': 'http://pbs.twimg.com/media/EFfjJMgVAAAIMBH.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EFfjJMgVAAAIMBH.jpg',
#        'url': 'https://t.co/FGifxsfYPH',
#        'display_url': 'pic.twitter.com/FGifxsfYPH',
#        'expanded_url': 'https://twitter.com/ewbcalgary/status/1177659582547496960/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#         'large': {'w': 1600, 'h': 1200, 'resize': 'fit'}}},
#       {'id': 1177659574716755968,
#        'id_str': '1177659574716755968',
#        'indices': [253, 276],
#        'media_url': 'http://pbs.twimg.com/media/EFfjJMlUcAAw_dO.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EFfjJMlUcAAw_dO.jpg',
#        'url': 'https://t.co/FGifxsfYPH',
#        'display_url': 'pic.twitter.com/FGifxsfYPH',
#        'expanded_url': 'https://twitter.com/ewbcalgary/status/1177659582547496960/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#         'large': {'w': 1600, 'h': 1200, 'resize': 'fit'}}}]}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 1,
#    'favorite_count': 1,
#    'entities': {'hashtags': [{'text': 'ClimateStrikeYYC',
#       'indices': [84, 101]}],
#     'urls': [{'url': 'https://t.co/faBfHPxfAq',
#       'expanded_url': 'https://twitter.com/i/web/status/1177659582547496960',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'ClimateStrikeYYC',
#      'indices': [100, 117]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'ewbcalgary',
#      'name': 'EWB Calgary',
#      'id': 16153555,
#      'id_str': '16153555',
#      'indices': [3, 14]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1569611019177'}]

# %% [markdown]
# ### Lets look at a single tweet, and see what fields we want for our DataFrame:
#
# Use json.dumps function, with an indent level to easily view the data.

# %%
print(json.dumps(tweets_data[2], indent=4, sort_keys=False))
#created_at, id, text, user (id, name, screen_name), followers_count, friends_count, favourites_count, profile_background_color
#profile_text_color,
# Out:
# {
#     "created_at": "Fri Sep 27 19:03:37 +0000 2019",
#     "id": 1177660081388871681,
#     "id_str": "1177660081388871681",
#     "text": "RT @TheBeaverton: Trudeau comes to Montreal climate strike to protest self #cdnpoli #elxn43 #ClimateStrikeCanada",
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "truncated": false,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 2393055440,
#         "id_str": "2393055440",
#         "name": "Darren Cargill \ud83c\udde8\ud83c\udde6",
#         "screen_name": "reasonablewlvrn",
#         "location": "Windsor, ON",
#         "url": null,
#         "description": "Father, Husband, PallMed MD in Windsor, ON. Going \ud83d\udc1d  RT = chat. Spelling \ud83d\udeab part of plan. speak GIPHY & \ud83d\ude45\ud83c\udffc\u200d trolls. Not a Bot #TrudeauMustGo #GoBlue #TB12\ud83d\udc10",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 2578,
#         "friends_count": 1910,
#         "listed_count": 109,
#         "favourites_count": 39860,
#         "statuses_count": 31072,
#         "created_at": "Sun Mar 16 17:39:32 +0000 2014",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1120864160349343744/nPbhW5nl_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1120864160349343744/nPbhW5nl_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/2393055440/1569180436",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "retweeted_status": {
#         "created_at": "Fri Sep 27 18:56:36 +0000 2019",
#         "id": 1177658314345324544,
#         "id_str": "1177658314345324544",
#         "text": "Trudeau comes to Montreal climate strike to protest self #cdnpoli #elxn43 #ClimateStrikeCanada",
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 149282848,
#             "id_str": "149282848",
#             "name": "The Beaverton",
#             "screen_name": "TheBeaverton",
#             "location": "North America",
#             "url": "http://www.thebeaverton.com",
#             "description": "Finally. The News. On Television. Watch our damn Election Special October 18th on @CTV",
#             "translator_type": "none",
#             "protected": false,
#             "verified": true,
#             "followers_count": 47330,
#             "friends_count": 288,
#             "listed_count": 459,
#             "favourites_count": 4967,
#             "statuses_count": 11768,
#             "created_at": "Fri May 28 22:18:50 +0000 2010",
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_link_color": "CC0000",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1064609270233128960/e4KT53qW_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1064609270233128960/e4KT53qW_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/149282848/1565189994",
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": null,
#             "follow_request_sent": null,
#             "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "quote_count": 0,
#         "reply_count": 4,
#         "retweet_count": 22,
#         "favorite_count": 50,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "cdnpoli",
#                     "indices": [
#                         57,
#                         65
#                     ]
#                 },
#                 {
#                     "text": "elxn43",
#                     "indices": [
#                         66,
#                         73
#                     ]
#                 },
#                 {
#                     "text": "ClimateStrikeCanada",
#                     "indices": [
#                         74,
#                         94
#                     ]
#                 }
#             ],
#             "urls": [],
#             "user_mentions": [],
#             "symbols": []
#         },
#         "favorited": false,
#         "retweeted": false,
#         "filter_level": "low",
#         "lang": "en"
#     },
#     "is_quote_status": false,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "entities": {
#         "hashtags": [
#             {
#                 "text": "cdnpoli",
#                 "indices": [
#                     75,
#                     83
#                 ]
#             },
#             {
#                 "text": "elxn43",
#                 "indices": [
#                     84,
#                     91
#                 ]
#             },
#             {
#                 "text": "ClimateStrikeCanada",
#                 "indices": [
#                     92,
#                     112
#                 ]
#             }
#         ],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "screen_name": "TheBeaverton",
#                 "name": "The Beaverton",
#                 "id": 149282848,
#                 "id_str": "149282848",
#                 "indices": [
#                     3,
#                     16
#                 ]
#             }
#         ],
#         "symbols": []
#     },
#     "favorited": false,
#     "retweeted": false,
#     "filter_level": "low",
#     "lang": "en",
#     "timestamp_ms": "1569611017926"
# }

# %% [markdown]
# All of the fields (I have deemed relevent) are listed below. An example of how to load each field is given;
# some of them are nested in sub-json objects (like the user object).

# %%
tweetObj  = tweets_data[2]

#Now, lets see how we can access all of our fields of interest:

#created_at
print(tweetObj["created_at"])
#id
print(tweetObj["id"])

#text
print(tweetObj["text"])

#user
#print(tweetObj["user"])

#user->id
print(tweetObj["user"]["id"])
#user->screen_name
#keep this for a basic user reference
print(tweetObj["user"]["screen_name"])


#user->name
#print(tweetObj["user"]["name"])
#I choose not to store the follower/friends data for a user; these can be looked up separately 
#causes largely-redundant columns.

#entities->hashtags [tag1, tag2, tag3...]
#our internal tweet objects are mini-dictionaries!
hashTagString = ""
if tweetObj["entities"]["hashtags"]:
    for item in tweetObj["entities"]["hashtags"]:
        hashTagString = hashTagString + "," + item["text"]
    hashTagString = hashTagString[1:] #removes the leading comma; i don't want a base-case above loop.
    print(hashTagString)

#quote count
print(tweetObj["quote_count"])

#reply count
print(tweetObj["reply_count"])

#favourite count
print(tweetObj["retweet_count"])

#relevent count
print(tweetObj["favorite_count"])
# Out:
# Fri Sep 27 19:03:37 +0000 2019
# 1177660081388871681
# RT @TheBeaverton: Trudeau comes to Montreal climate strike to protest self #cdnpoli #elxn43 #ClimateStrikeCanada
# 2393055440
# reasonablewlvrn
# cdnpoli,elxn43,ClimateStrikeCanada
# 0
# 0
# 0
# 0

# %% [markdown]
# ### Experiment 1: Make a Dataframe from 3 large files:
#
# Here, 3 full csvs are loaded. A selection of user and top level fields are put in the data frame. Its size,
# and compression are measured.

# %%
#Lets read in the tweets, and convert them to a DataFrame
topLevelFields = ["created_at", "id", "text"]

userFields = ["id", "name", "screen_name", "followers_count", 
              "friends_count", "favourites_count", "profile_background_color","profile_text_color"]

#make an empty DF.
tweetDF = pd.DataFrame(columns=topLevelFields + list(map(lambda x: "user_" + x , userFields)))

baseDir = "/home/sean/ca_election_tweets/data/"
commList = ["comments1.json","comments2.json","comments3.json"]

def parsetweet(jsonObj):
    retList = []
    for label in topLevelFields:
        retList.append(jsonObj[label])
        
    for label in userFields:
        retList.append(jsonObj["user"][label])
    return retList

#build a beast...
with open(baseDir + "comments1.json", "r") as tweets_file:
    for i,line in enumerate(tweets_file):
        try:
            tweet = json.loads(line)
            retList = parsetweet(tweet)
            tweetDF.loc[tweetDF.shape[0]] = retList
            
        except ValueError as e:
            print('Handling run-time error:', e)            
    tweets_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-d652ba801b1e> in <module>
#      21
#      22 #build a beast...
# ---> 23 with open(baseDir + "comments1.json", "r") as tweets_file:
#      24     for i,line in enumerate(tweets_file):
#      25         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sean/ca_election_tweets/data/comments1.json'

# %%
#Memory usage before casting
tweetDF.memory_usage(index=True,deep=True).sum()
# Out:
# 17457200

# %%
#Now lets convert our datatypes accordingly
tweetDF["id"] = tweetDF["id"].astype("int")
tweetDF["user_id"] = tweetDF["user_id"].astype("int")
tweetDF["user_followers_count"] = tweetDF["user_followers_count"].astype("int32")
tweetDF["user_friends_count"] = tweetDF["user_friends_count"].astype("int32")
tweetDF["user_favourites_count"] = tweetDF["user_favourites_count"].astype("int32")

# %%
#Memory usage before casting
tweetDF.memory_usage(index=True,deep=True).sum()
# Out:
# 14210628

# %%
tweetDF.head()
# Out:
#                        created_at   id  \
# 0  Fri Sep 27 19:03:37 +0000 2019  NaN
# 1  Fri Sep 27 19:03:37 +0000 2019  NaN
# 2  Fri Sep 27 19:03:37 +0000 2019  NaN
# 3  Fri Sep 27 19:03:37 +0000 2019  NaN
# 4  Fri Sep 27 19:03:39 +0000 2019  NaN
#
#                                                 text              user_id  \
# 0  RT @CanadianGreens: This is a moment in histor...            172399876
# 1  RT @tylerwhat16: Y’all better be going out lik...             39512124
# 2  RT @AndreeLyne_H: Justin Trudeau is promising ...             16272844
# 3  RT @TheBeaverton: Trudeau comes to Montreal cl...           2393055440
# 4  RT @ewbcalgary: It may have rained and snowed ...  1171638022787543040
#
#                user_name user_screen_name user_followers_count  \
# 0       cynthia w Nelson         cindian1                  473
# 1        Under the Radar   retail_recruit                 3389
# 2  Greg Johansen 🏳️‍🌈 🐓🍷        johangreg                 3198
# 3      Darren Cargill 🇨🇦  reasonablewlvrn                 2578
# 4                debwong    deborahwongsy                   16
#
#   user_friends_count user_favourites_count user_profile_background_color  \
# 0               2045                 10539                        000000
# 1               4497                179789                        000000
# 2               1179                220678                        C0DEED
# 3               1910                 39860                        C0DEED
# 4                 83                    59                        F5F8FA
#
#   user_profile_text_color
# 0                  000000
# 1                  000000
# 2                  333333
# 3                  333333
# 4                  333333

# %%
userFields = ["id", "name", "screen_name", "followers_count", 
              "friends_count", "favourites_count", "profile_background_color","profile_text_color"]
# Out:
# ['user_id',
#  'user_name',
#  'user_screen_name',
#  'user_followers_count',
#  'user_friends_count',
#  'user_favourites_count',
#  'user_profile_background_color',
#  'user_profile_text_color']

# %%
#Appending rows with loc:
#Nice Trick by user Qinsi on page: https://stackoverflow.com/questions/26309962/appending-a-list-or-series-to-a-pandas-dataframe-as-a-row
myDF = pd.DataFrame({"A":[1,2,3],"B":[1,2,3]})
myDF.loc[4] = [4,4]

# %% [markdown]
# ### Total Memory Estimate (in RAM):
#
# One 150mb file, with a subset of columns loaded, and data types optimized, turned about to be ~15mb.
# Most fields in our tweet json object are not useful. Suppose that our maximum DF size per file is about 50mb
# We will not exceed about 500 tweet files (20000 tweets per file).
#
# This gives us 500 * 50 = 25000 MB ~ 25GB. The entire tweet dataframe could technically be loaded into memory

# %% [markdown]
# ### Experimental Code 1:
#
# Lets load 5 files, and make two tables (for users and tweets).

# %%
#Simple Timeit usage https://stackoverflow.com/questions/7370801/measure-time-elapsed-in-python

timeStart = time.time()
timeEnd = time.time()

 





def get3frames():
    def parsetweet(jsonObj):
        retList = []
        for label in topLevelFields: #last one doesn't exist!
            retList.append(jsonObj[label])

        hashTagString = ""
        if jsonObj["entities"]["hashtags"]:
            for item in jsonObj["entities"]["hashtags"]:
                hashTagString = hashTagString + "," + item["text"]
            hashTagString = hashTagString[1:]
        retList.append(hashTagString)
        return retList       

    def parseuser(jsonObj):
        #first, extract id from jsonObj for user. Is it in our table of users?
        #To check (quickly) for a users presence, we need a hash table.
        #In python, dictionaries serve the same purpose
        retList = []
        if jsonObj["user"]["id"] not in userCheckDict:
            userCheckDict[id] = 1
            for label in userFields:
                retList.append(jsonObj["user"][label])
        else:
            sameUserCount = sameUserCount + 1   
        return retList
    
    
    #Lets read in the tweets, and convert them to a DataFrame
    topLevelFields = ["id", "created_at", "text","quote_count","reply_count","retweet_count","favorite_count"]

    userFields = ["id", "created_at", "name", "screen_name", "verified", "followers_count", 
                  "friends_count", "favourites_count", "statuses_count", 
                 "profile_background_color","profile_text_color"]

    userCheckDict = {"test": 1}

    sameUserCount = 0

    #make an empty DF.
    tweetDF = pd.DataFrame(columns=topLevelFields + ["hashtag_list"])
    userDF = pd.DataFrame(columns=userFields)  #list(map(lambda x: "user_" + x , userFields)))

    baseDir = "./data/"
    commList = ["comments1.json","comments2.json","comments3.json"]
    
    
    
    with open(baseDir + filename, "r") as tweets_file:
        for i,line in enumerate(tweets_file):
            try:
                tweet = json.loads(line)
                tweetDF.loc[tweetDF.shape[0]] = parsetweet(tweet)
                retList = parseuser(tweet)
                if retList: #Not empty: 
                    userDF.loc[userDF.shape[0]] = retList
            except ValueError as e:
                print('Handling run-time error:', e)            
        tweets_file.close()

# %%
        
#build a beast...

    with open(baseDir + filename, "r") as tweets_file:
        for i,line in enumerate(tweets_file):
            try:
                tweet = json.loads(line)
                tweetDF.loc[tweetDF.shape[0]] = parsetweet(tweet)
                retList = parseuser(tweet)
                if retList: #Not empty: 
                    userDF.loc[userDF.shape[0]] = retList
            except ValueError as e:
                print('Handling run-time error:', e)            
        tweets_file.close()


tweetDF.sample(n=10)
tweetDF.shape
print("tweetDF memory:" + str(tweetDF.memory_usage(index=True,deep=True).sum()))
userDF.sample(n=10)
userDF.shape
print("UserDF memory:" + str(userDF.memory_usage(index=True,deep=True).sum()))
print("Time to Execute 3 Files in Total: " + str(timeEnd - timeStart))

userDF.to_csv("./data/userDF.csv")
tweetDF.to_csv("./data/tweetDF.csv")

# %%
### Experiment 2: Lets do all 20 DFs:

timeStart = time.time()
#relies on funcitons in Experiment 1.
#get comment list

import glob
baseDir = "./data/tweets/"
commList = glob.glob(baseDir+"*")

#build a beast...
for filename in commList: #Note: Glob list gives path from relative root directory!
    with open(filename, "r") as tweets_file:
        for i,line in enumerate(tweets_file):
            try:
                tweet = json.loads(line)
                tweetDF.loc[tweetDF.shape[0]] = parsetweet(tweet)
                retList = parseuser(tweet)
                if retList: #Not empty: 
                    userDF.loc[userDF.shape[0]] = retList
            except ValueError as e:
                print('Handling run-time error:', e)            
        tweets_file.close()



timeEnd = time.time()
tweetDF.sample(n=5)
tweetDF.shape
print("tweetDF memory:" + str(tweetDF.memory_usage(index=True,deep=True).sum()))
userDF.sample(n=5)
userDF.shape
print("UserDF memory:" + str(userDF.memory_usage(index=True,deep=True).sum()))
print("Number of duplicate users detected:" + str(sameUserCount))
print("Time to Execute 20 Files in Total: " + str(timeEnd - timeStart))

userDF.to_csv("./data/userDF.csv")
tweetDF.to_csv("./data/tweetDF.csv")
# Out:
# Handling run-time error: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-61d5ea261db9> in <module>
#      18                 retList = parseuser(tweet)
#      19                 if retList: #Not empty:
# ---> 20                     userDF.loc[userDF.shape[0]] = retList
#      21             except ValueError as e:
#      22                 print('Handling run-time error:', e)
#
# ~/DSDEenv/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     200             key = com.apply_if_callable(key, self.obj)
#     201         indexer = self._get_setitem_indexer(key)
# --> 202         self._setitem_with_indexer(indexer, value)
#     203
#     204     def _validate_key(self, key, axis: int):
#
# KeyboardInterrupt:

# %%
baseDir = "./data/tweets/"
commList = glob.glob(baseDir+"*")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9b4a27dbbe6f> in <module>
#       1 baseDir = "./data/tweets/"
# ----> 2 commList = glob.glob(baseDir+"*")
#
# NameError: name 'glob' is not defined
